# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner and combine it with our other data skills. In this lab you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer follow-up questions.
#
#
# ### Outline:
#
# 1. Determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create Python functions to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# *Something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data*
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - What are the 5 businesses with the highest average ratings?
# - What are the 5 businesses with the lowest average ratings?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - How many businesses have a rating greater than or  4.5?
# - How many businesses have a rating less than 3?
# - Return the text of the reviews for the most reviewed restaurant.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %%
import requests
import json
import mysql.connector
import config
from mysql.connector import errorcode
import time

# %% [markdown]
# ## Part I - Set up the DB
#
# Start by reading SQL questions above to get an understanding of the data you will need. Then, read the documentation of Yelp API to understand what data you will receive in the response.
#
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %%
## Connect to DB server on AWS ##### REMEMBER TO COMMIT UPDATES TO DB!!!!!
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    database = 'yelp'
)

# %%
cursor = cnx.cursor()

# %%
## Create new DB 
db_name = 'yelp'

# %%
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)
# Out:
# Database yelp does not exists.
# Database yelp created successfully.

# %%
# Create a table for the Businesses
tables = {}
tables['businesses'] = (
    "CREATE TABLE businesses ("
    "  id varchar(50) NOT NULL,"
    "  name varchar(50) NOT NULL,"
    "  rating float(32),"
    "  price varchar(10),"
    "  PRIMARY KEY (id)"
    ") ENGINE=InnoDB")

# %%
# Create a table for the reviews
tables['reviews'] = (
    "CREATE TABLE reviews ("
    "  id varchar(50) NOT NULL,"
    "  text varchar(1000),"
    "  PRIMARY KEY (id)"
    ") ENGINE=InnoDB")

# %%
for table_name in tables:
    table_description = tables[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table businesses: OK
# Creating table reviews: OK

# %%
# ALTER TABLE TableName
# ADD ColumnName Datatype;

stmt = """ALTER TABLE businesses ADD review_count INT(10)"""
cursor.execute(stmt)

# %% [markdown]
# ## Part 2: Create ETL pipeline for the business data from the API

# %%
# write a function to make a call to the DB
url = "https://api.yelp.com/v3/businesses/search"
api_key = 'OG1R6QqOCWoDZmudlnvFACy8MDm2UPvWfvGSkz6Fv2mLrbjU1q5__1eXA-T6TWE5vacDopfDXZnk2qdjnUd6ZORJiNRPyFi5Sj_nhDE7H710VPbZrRjjkTlRL9SxXXYx'
header = {'Authorization': 'Bearer %s' %api_key}
params = {'term': 'pizza',
         'location':'East Village, NY',
          'limit' : '50'
         }

# %%
def request_from_yelp(url, header, params):
    req = requests.get(url, params=params, headers=header)
    data = json.loads(req.content)
    return data
def all_results(url,header,params):
    num = request_from_yelp(url, params=params, header=header)['total']
    print('{} total matches found.'.format(num))
    cur = 0
    results = []
    while cur < num and cur < 1000:
        params['offset'] = str(cur)
        results.append(request_from_yelp(url, params=params, header=header))
        time.sleep(1) #Wait a second
        cur += 50
    return results

# %%
results = all_results(url=url, header=header, params=params)
# Out:
# 1400 total matches found.

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'businesses': [{'alias': 'prince-street-pizza-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'display_phone': '(212) 966-4100',
#    'distance': 1119.7297932868187,
#    'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['27 Prince St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Prince Street Pizza',
#    'phone': '+12129664100',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 3177,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'village-square-pizza-new-york-3',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#    'display_phone': '(917) 675-7709',
#    'distance': 63.3752711218174,
#    'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '147 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['147 Ave A', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Village Square Pizza',
#    'phone': '+19176757709',
#    'rating': 4.5,
#    'review_count': 97,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.730616, 'longitude': -73.9834846},
#    'display_phone': '(212) 473-7447',
#    'distance': 409.75408421707186,
#    'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '211 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['211 1st Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Luzzos La Pizza Napoletana',
#    'phone': '+12124737447',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1026,
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'gruppo-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#    'display_phone': '(212) 995-2100',
#    'distance': 262.0526804436815,
#    'id': 'MeQU-nGaQvX12VXYOyzavQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mCZI4W3FgjwMS-G054lxZw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '98 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['98 Ave B', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Gruppo',
#    'phone': '+12129952100',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 250,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'joes-pizza-new-york-7',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#    'display_phone': '(212) 388-9474',
#    'distance': 815.1282265888377,
#    'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['150 E 14th St', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': "Joe's Pizza",
#    'phone': '+12123889474',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 834,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'lombardis-pizza-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'display_phone': '(212) 941-7994',
#    'distance': 1268.4647736267825,
#    'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['32 Spring St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': "Lombardi's Pizza",
#    'phone': '+12129417994',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 5988,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'rizzos-fine-pizza-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'coordinates': {'latitude': 40.720852, 'longitude': -73.984456},
#    'display_phone': '(646) 454-1262',
#    'distance': 709.2906278638177,
#    'id': 'nUpA3sY5b6dynC7aj0eV6A',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnLj-NVZx4TUp608hDVBvw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '17 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['17 Clinton St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': "Rizzo's Fine Pizza",
#    'phone': '+16464541262',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 712,
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'bakers-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#    'display_phone': '(212) 777-7477',
#    'distance': 285.41522345853633,
#    'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3TbUAZcHe7PQ278pONEU0w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['201 Avenue A', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': "Baker's Pizza",
#    'phone': '+12127777477',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 197,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'artichoke-basilles-pizza-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'display_phone': '(212) 228-2004',
#    'distance': 579.8618546809496,
#    'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['321 E 14th St', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': "Artichoke Basille's Pizza",
#    'phone': '+12122282004',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 3894,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'joe-and-pats-pizzeria-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.72892, 'longitude': -73.98411},
#    'display_phone': '(212) 677-4992',
#    'distance': 251.02854528136152,
#    'id': '0ROpM3UcZhprN6dhwK2Hsw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/54SAnkVg790vhVkC5sT1IQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '168 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['168 1st Ave', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': "Joe & Pat's Pizzeria",
#    'phone': '+12126774992',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 142,
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'url': 'https://www.yelp.com/biz/joe-and-pats-pizzeria-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'protos-pizza-new-york-9',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.725353, 'longitude': -73.989746},
#    'display_phone': '(212) 432-4044',
#    'distance': 656.6896710043255,
#    'id': 'VrP6mI9Ihf2qt8dH6XwnYg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AdbSxI5lZGb6EBFJfvQAOQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '50 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['50 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': "Proto's Pizza",
#    'phone': '+12124324044',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 97,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/protos-pizza-new-york-9?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'east-village-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 40.72823, 'longitude': -73.9852499},
#    'display_phone': '(212) 529-4545',
#    'distance': 272.7551553084531,
#    'id': 'oOr6Ta5gZyDl6PyZ1cq7pg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pKsqDzsdqJ9pp9HZaeB7Ng/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '145 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['145 1st Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'East Village Pizza',
#    'phone': '+12125294545',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 211,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/east-village-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'l-industrie-pizzeria-brooklyn',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'display_phone': '(718) 599-0002',
#    'distance': 2685.265802761495,
#    'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211'],
#     'state': 'NY',
#     'zip_code': '11211'},
#    'name': "L'industrie Pizzeria",
#    'phone': '+17185990002',
#    'price': '$',
#    'rating': 5.0,
#    'review_count': 484,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'sorbillo-pizzeria-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'coordinates': {'latitude': 40.726, 'longitude': -73.99218},
#    'display_phone': '(646) 476-8049',
#    'distance': 843.9735928589931,
#    'id': 'ZxobXn7eEYDOzQKYHH9ARQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/osvrl79m2WD1rYgfZFBrHA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '334 Bowery',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['334 Bowery', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Sorbillo Pizzeria',
#    'phone': '+16464768049',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 162,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/sorbillo-pizzeria-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'motorino-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#    'display_phone': '(212) 777-2644',
#    'distance': 390.91210635636486,
#    'id': 'S8OKQ5S40oZ1Rr5RbC0jdg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QD5ot0KVIpX7wSNs0sfhwg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '349 E 12th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['349 E 12th St', 'Ste A', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Motorino',
#    'phone': '+12127772644',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 1074,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/motorino-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'solo-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'}],
#    'coordinates': {'latitude': 40.7223854064941, 'longitude': -73.98291015625},
#    'display_phone': '(212) 420-7656',
#    'distance': 518.5545738011563,
#    'id': 'sckXpoL2O6ZCGfoVsgi2ww',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-fd2uo6fxL8_IrwMyFGBzw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '27 Avenue B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['27 Avenue B', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Solo Pizza',
#    'phone': '+12124207656',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 183,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/solo-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'mani-in-pasta-new-york',
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7326, 'longitude': -73.98515},
#    'display_phone': '(646) 891-0174',
#    'distance': 669.8035039013296,
#    'id': 'Bk7METp9hGgm409E6EoBhw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UZo7l4af4DTFBXNEHV9Nqw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '245 E 14th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['245 E 14th St', 'New York, NY 10016'],
#     'state': 'NY',
#     'zip_code': '10016'},
#    'name': 'Mani In Pasta',
#    'phone': '+16468910174',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 80,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/mani-in-pasta-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'lions-and-tigers-and-squares-detroit-pizza-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72981, 'longitude': -73.98658},
#    'display_phone': '',
#    'distance': 463.8893467326993,
#    'id': '2ZALEmIVm_t4tYLGXxd2dw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v6HP9EMBhvDb8Jyj1geBWQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '160 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['160 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Lions & Tigers & Squares Detroit Pizza',
#    'phone': '',
#    'rating': 4.0,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lions-and-tigers-and-squares-detroit-pizza-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'sauce-pizzeria-new-york-5',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7204894, 'longitude': -73.98927},
#    'display_phone': '(917) 675-7240',
#    'distance': 931.5663466038247,
#    'id': 'H_Q1dEqnrz7GzQiArdsrNw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7N9pnpiO7AmA01GvkPYk3g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '84 Rivington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['84 Rivington St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'Sauce Pizzeria',
#    'phone': '+19176757240',
#    'rating': 4.0,
#    'review_count': 26,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/sauce-pizzeria-new-york-5?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'la-margarita-pizzeria-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'display_phone': '(917) 261-4983',
#    'distance': 754.7548388327207,
#    'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'La Margarita Pizzeria',
#    'phone': '+19172614983',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 280,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'emmy-squared-east-village-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 40.72598, 'longitude': -73.98672},
#    'display_phone': '(917) 463-3737',
#    'distance': 391.7167088953111,
#    'id': 'nfZUADLfijRalf1kknJJCw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zORAnfCvPw4xZZinxwEeAA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '83 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['83 1st Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Emmy Squared - East Village',
#    'phone': '+19174633737',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 154,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/emmy-squared-east-village-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'numero-28-pizzeria-napoletana-new-york-3',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.73041, 'longitude': -73.98595},
#    'display_phone': '(212) 777-1555',
#    'distance': 482.8101428283673,
#    'id': 'GqTgQEqwf3k5JyE7DHDhjw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wWU766LZqifH0GSflhzlxg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '176 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['176 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Numero 28 Pizzeria Napoletana',
#    'phone': '+12127771555',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 518,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/numero-28-pizzeria-napoletana-new-york-3?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'nolita-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.72834, 'longitude': -73.98764},
#    'display_phone': '(646) 756-4141',
#    'distance': 466.5868439326347,
#    'id': 'cdkPnLb1Sr2gGnoYsrR5BQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m372fb2o_EAmLuXLs1W5Hg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '128 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['128 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Nolita Pizza',
#    'phone': '+16467564141',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 12,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/nolita-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'rubirosa-new-york-2',
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'display_phone': '(212) 965-0500',
#    'distance': 1259.5275933984428,
#    'id': 'WG639VkTjmK5dzydd1BBJA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Rubirosa',
#    'phone': '+12129650500',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 2069,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'sauce-pizzeria-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.73033, 'longitude': -73.98403},
#    'display_phone': '(646) 983-4007',
#    'distance': 400.77726926402266,
#    'id': 'd8USIZvTTqee35l34anRBg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VoSXYh3NdJuHhD68i1IQIQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '345 E 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['345 E 12th St', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Sauce Pizzeria',
#    'phone': '+16469834007',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 156,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/sauce-pizzeria-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'lil-frankies-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#    'display_phone': '(212) 420-4900',
#    'distance': 636.4576263292937,
#    'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4_d7ZxSNaJVLaNEFhxbOAw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '19 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['19 1st Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': "Lil' Frankie's",
#    'phone': '+12124204900',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1055,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'loverboy-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 40.72488, 'longitude': -73.97858},
#    'display_phone': '(212) 539-1900',
#    'distance': 398.09017796482175,
#    'id': '1A2-oW9IRHSzVzo-iouI3g',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fN0M4R1gVw5yRF-7Q-iCUg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '127 Avenue C',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['127 Avenue C', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Loverboy',
#    'phone': '+12125391900',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 44,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/loverboy-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': '2-bros-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72866, 'longitude': -73.988487},
#    'display_phone': '(212) 777-0600',
#    'distance': 546.4442573484436,
#    'id': 'f_cPl8sxSbVxdEivg0DAFw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mfRJAf6bWR3WES5EtU_TYA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '32 St Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['32 St Marks Pl', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': '2 Bros Pizza',
#    'phone': '+12127770600',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 592,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/2-bros-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'two-boots-east-village-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72369, 'longitude': -73.98489},
#    'display_phone': '(212) 254-1919',
#    'distance': 430.04710352425,
#    'id': 'asxQ9Kf3RjigsftsTVk53A',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FAWaK_8UhISNCGOI2KCcwQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '42 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['42 Ave A', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Two Boots East Village',
#    'phone': '+12122541919',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 355,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/two-boots-east-village-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'joes-pizza-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.730655, 'longitude': -74.002189},
#    'display_phone': '(212) 366-1182',
#    'distance': 1717.193023867545,
#    'id': 'uc5qQMzs96rzjK27epDCug',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['7 Carmine St', 'New York, NY 10014'],
#     'state': 'NY',
#     'zip_code': '10014'},
#    'name': "Joe's Pizza",
#    'phone': '+12123661182',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 2426,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'tramonti-la-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.72667, 'longitude': -73.9836},
#    'display_phone': '(212) 260-1441',
#    'distance': 109.84055375595219,
#    'id': 'Cm_knZN7W1MaFEp8MkBBSA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wXHvlqX_y6UWPTNnOJEp5w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '130 Saint Marks Pl',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['130 Saint Marks Pl', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Tramonti La Pizza',
#    'phone': '+12122601441',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 119,
#    'transactions': ['pickup'],
#    'url': 'https://www.yelp.com/biz/tramonti-la-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'posto-new-york-4',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.73483, 'longitude': -73.98282},
#    'display_phone': '(212) 716-1200',
#    'distance': 867.2001778597762,
#    'id': 'X8Hl9OezX-Yr9Jir3fsF7g',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GNK1zpfkMKebOq7U5ljZqg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '310 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['310 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Posto',
#    'phone': '+12127161200',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 591,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/posto-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'johns-of-bleecker-street-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'display_phone': '(212) 243-1680',
#    'distance': 1848.4216016035425,
#    'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ey_5ReYpouWm4SlY2DsaVQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014'],
#     'state': 'NY',
#     'zip_code': '10014'},
#    'name': "John's of Bleecker Street",
#    'phone': '+12122431680',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1926,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'nolita-pizza-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7208883, 'longitude': -73.9962404},
#    'display_phone': '(646) 895-9131',
#    'distance': 1354.2950982455218,
#    'id': 'vpkTNjq9dRh9rT3Nh0pe-A',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2xMQ-9x-jE51i03y0ana5g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '68 Kenmare St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['68 Kenmare St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Nolita Pizza',
#    'phone': '+16468959131',
#    'rating': 5.0,
#    'review_count': 6,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/nolita-pizza-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'speedy-romeo-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.71951, 'longitude': -73.98514},
#    'display_phone': '(212) 529-6300',
#    'distance': 869.1581773164548,
#    'id': 'EYSIZX7b6Sp6TNc_KNvn7Q',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fJgnkrWbs6oMD_X5WHDMyw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '63 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['63 Clinton St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'Speedy Romeo',
#    'phone': '+12125296300',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 288,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/speedy-romeo-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'bleecker-street-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'display_phone': '(212) 924-4466',
#    'distance': 1861.866933185996,
#    'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014'],
#     'state': 'NY',
#     'zip_code': '10014'},
#    'name': 'Bleecker Street Pizza',
#    'phone': '+12129244466',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 2250,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'and-pizza-new-york-10',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.729798, 'longitude': -73.9926904},
#    'display_phone': '(202) 558-7549',
#    'distance': 923.066131346886,
#    'id': '51xuge-nOovXRTU_o0G0gA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFDkd7_Beu9_vrRNIpKhnw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '740 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['740 Broadway', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': '&pizza',
#    'phone': '+12025587549',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 138,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/and-pizza-new-york-10?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'midici-neapolitan-pizza-brooklyn',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.71529, 'longitude': -73.95858},
#    'display_phone': '(718) 782-2020',
#    'distance': 2388.937305214696,
#    'id': 'Zjj8JkJm0yRyrUFffr7Eww',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9IgOboH53L7XYsvt_E1QSA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '174 N 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['174 N 4th St', 'Brooklyn, NY 11211'],
#     'state': 'NY',
#     'zip_code': '11211'},
#    'name': 'MidiCi Neapolitan Pizza',
#    'phone': '+17187822020',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 30,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/midici-neapolitan-pizza-brooklyn?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'neapolitan-express-new-york-7',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'coordinates': {'latitude': 40.7247, 'longitude': -73.99087},
#    'display_phone': '',
#    'distance': 763.0266445804723,
#    'id': 'k4ZtjGOt0e7oQ7Ut81ZwTA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h_1MgeiB4myDgRNZme1YaA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '29 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['29 2nd Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Neapolitan Express',
#    'phone': '',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 7,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/neapolitan-express-new-york-7?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'bd-star-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'coordinates': {'latitude': 40.72542, 'longitude': -73.98418},
#    'display_phone': '(212) 505-1200',
#    'distance': 237.61282063746302,
#    'id': 'pAnaw43SmxgT94Ahy5845g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lnTsANy6YQCAibNt9QyNeg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '91 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['91 Ave A', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'BD Star Pizza',
#    'phone': '+12125051200',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 15,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/bd-star-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'eleven-b-new-york-4',
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 40.72745, 'longitude': -73.97974},
#    'display_phone': '(212) 388-9811',
#    'distance': 223.5667180104071,
#    'id': 'Hc0p6xWxJthMZIlckFzgZA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lx2zMB7HsznHPv3PkBP5xA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '174 Avenue B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['174 Avenue B', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Eleven B',
#    'phone': '+12123889811',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 204,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/eleven-b-new-york-4?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'la-nonna-krispy-krust-pizza-brooklyn',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.717953, 'longitude': -73.9637027},
#    'display_phone': '(347) 384-2100',
#    'distance': 1868.590682868749,
#    'id': '6ECcDYsRgmfv0eKXk-c11Q',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/snKP9CUQHOth_2vox3Z79g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '175 Kent Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['175 Kent Ave', 'Brooklyn, NY 11211'],
#     'state': 'NY',
#     'zip_code': '11211'},
#    'name': 'La Nonna Krispy Krust Pizza',
#    'phone': '+13473842100',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 34,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/la-nonna-krispy-krust-pizza-brooklyn?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'williamsburg-pizza-new-york-3',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.71822, 'longitude': -73.99123},
#    'display_phone': '(212) 226-4455',
#    'distance': 1225.74005930534,
#    'id': '58YvTYsyxNyGixTAZiMHcg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uMXAMUisv9ehDKRBKDU9DQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '277 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['277 Broome St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'Williamsburg Pizza',
#    'phone': '+12122264455',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 210,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/williamsburg-pizza-new-york-3?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'scarrs-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#    'display_phone': '(212) 334-3481',
#    'distance': 1508.3964006564338,
#    'id': 'hGksyTiHBBdrhbiVjXzWVw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k3iXzXNevY7-CuIbE0-FaQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '22 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['22 Orchard St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': "Scarr's Pizza",
#    'phone': '+12123343481',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 309,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'f-and-m-slice-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7256757608813,
#     'longitude': -73.9779283976702},
#    'display_phone': '(347) 916-6922',
#    'distance': 402.8876602231334,
#    'id': 'chd7mX9ZTMvEkqc1D83Osw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b2fVYFwFEu7_v3Uejvy_YQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '153 Ave C',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['153 Ave C', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'F & M Slice Pizza',
#    'phone': '+13479166922',
#    'price': '$',
#    'rating': 3.0,
#    'review_count': 12,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/f-and-m-slice-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'stanton-pizza-new-york-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.72073, 'longitude': -73.98671},
#    'display_phone': '(212) 533-4252',
#    'distance': 789.0795817159243,
#    'id': 'kcvynqRHM79DOPrOS_OayA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JrHDe6Mfldt5GeuRaOdSyw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '127 Stanton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['127 Stanton St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'Stanton Pizza',
#    'phone': '+12125334252',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 189,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/stanton-pizza-new-york-2?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'champion-pizza-new-york-6',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.7215270996094,
#     'longitude': -73.9970855712891},
#    'display_phone': '(212) 226-3777',
#    'distance': 1379.8245379845553,
#    'id': 'atbANdSznV29GI066I2Ijw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SV5N-uxEa1tHUXYLAi43xA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Champion Pizza',
#    'phone': '+12122263777',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 294,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'ribalta-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'coordinates': {'latitude': 40.7334346, 'longitude': -73.9916923},
#    'display_phone': '(212) 777-7781',
#    'distance': 1060.7104947351174,
#    'id': 'CAGAWbPE8uPr2VVvEnv0ZA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O6RftJPph1inJ4dbf6o3rw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '48 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['48 E 12th St', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Ribalta Pizza',
#    'phone': '+12127777781',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 538,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/ribalta-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'stromboli-pizza-new-york',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.72778, 'longitude': -73.9854299},
#    'display_phone': '(212) 673-3691',
#    'distance': 269.95347242877415,
#    'id': 'rCFCyKkPuLDrZLNZiLJOHw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qptoEeOhGVwhjrlQVD3e5Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '83 Saint Marks Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['83 Saint Marks Pl', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Stromboli Pizza',
#    'phone': '+12126733691',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 213,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/stromboli-pizza-new-york?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'},
#   {'alias': 'lombardis-pizza-new-york-3',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 40.74623, 'longitude': -73.9974},
#    'display_phone': '(212) 256-1973',
#    'distance': 2485.5449633147714,
#    'id': 'DLsqhCGZmEo48zsgduCbpQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-8Id7zSey3eX2z7dsinGGg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '290 8th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['290 8th Ave', 'New York, NY 10001'],
#     'state': 'NY',
#     'zip_code': '10001'},
#    'name': "Lombardi's pizza",
#    'phone': '+12122561973',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 110,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-3?adjust_creative=VtPRsqqMAjvCbjZ2iKDzZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VtPRsqqMAjvCbjZ2iKDzZw'}],
#  'region': {'center': {'latitude': 40.72703039588718,
#    'longitude': -73.98236274719238}},
#  'total': 1400}

# %%
def parser(item):
    if 'id' not in item.keys():
        continue
    if 'price' not in item.keys():
        bus = {
        'id' : item['id'],
        'name' : item['name'],
        'rating' : item['rating'],
        'price' : 0,
        'review_count' : item['review_count']}
    else:
        bus = {
        'id' : item['id'],
        'name' : item['name'],
        'rating' : item['rating'],
        'price' : item['price'],
        'review_count' : item['review_count']}

    return bus
# Out:
#   File "<ipython-input-26-99d902e635c0>", line 4
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
to_sql =[]
for item in results:
    to_sql.append(parser(item))
flat_sql=[]
for x in to_sql:
    for y in x:
        flat_sql.append(y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-12ab95ed551a> in <module>()
#       1 to_sql =[]
#       2 for item in results:
# ----> 3     to_sql.append(parser(item))
#       4 flat_sql=[]
#       5 for x in to_sql:
#
# <ipython-input-24-66fd01b00827> in parser(item)
#       3     if 'price' not in item.keys():
#       4             bus = {
# ----> 5         'id' : item['id'],
#       6         'name' : item['name'],
#       7         'rating' : item['rating'],
#
# KeyError: 'id'

# %%
flat_sql[0:2]
# Out:
# ['id', 'name']

# %%
# write a function to parse the API response 

# so that you can easily insert the data in to the DB

# %%
# Write a function to take your parsed data and insert it into the DB
def insert_restaurant(my_dict):
    stmt = """INSERT INTO businesses
    (id, name, rating, price, review_count)
    VALUES (%(id)s,%(name)s,%(rating)s,%(price)s, %(review_count)s)"""
    cursor.execute(stmt, my_dict)


def load_sql(list_dicts):
    first = """INSERT INTO businesses (id, name, rating, price, review_count) VALUES"""
    str_list = []
    for item in list_dicts:
        second = item.values()
        second = [str(x) + ', 'for x in second ]
        second = ''.join(second)[:-2]
        second = '('+ second + ')'
        str_list.append(first + second)
    return str_list

# %%
cursor.execute("""TRUNCATE table businesses""")

# %% [markdown]
# ## Part 3: Create ETL pipeline for the restaurant review data from the API

# %%
# write a query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

# %%
# write a function that takes a business id 
# and makes a call to the API for reivews
# then parse out the relevant information

# %%
# write a function to insert the parsed data into the reviews table

# %% [markdown]
# ## Part 4: Write SQL queries that will answer the questions posed.

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter.***

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
import time

def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    
    data = response.json()['businesses']
    return data

def all_results(url_params, api_key):
    num = response.json()['total']
    print('{} total matches found.'.format(num))
    cur = 0
    results = []
    while cur < num and cur < 1000:
        url_params['offset'] = cur
        results.append(yelp_call(url_params, api_key))
        time.sleep(1) #Wait a second
        results += 50
    return df

term = 'pizza'
location = 'Astoria NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50
             }
df = all_results(url_params, api_key)
print(len(df))
df.head()

# %% [markdown]
# ### Sample SQL Query
#
# Below is a SQL query to create a table.  Additionally here is a link to create a table with a foreign key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/
#
# ```CREATE TABLE IF NOT EXISTS tasks (
#     task_id INT AUTO_INCREMENT,
#     title VARCHAR(255) NOT NULL,
#     start_date DATE,
#     due_date DATE,
#     status TINYINT NOT NULL,
#     priority TINYINT NOT NULL,
#     description TEXT,
#     PRIMARY KEY (task_id)
# )  ENGINE=INNODB;```
